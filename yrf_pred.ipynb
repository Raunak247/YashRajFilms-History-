# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\yrf.csv")

# %%
df.head(3)
# Out:
#     YRF Movies(Produced)  Box Office Collection (India in CR)  Budget (in Cr)  \
# 0  Daag : A poem of Love                                 3.25            0.95
# 1          Kabhie Kabhie                                 4.00            1.20
# 2           Doosra Aadmi                                  NaN             NaN
#
#    Release Year           Genre  IMDB Rating (out of 10) Director's Name  \
# 0          1973  Romance ,Drama                      7.0     Yash Chopra
# 1          1976  Romance ,Drama                      7.2     Yash Chopra
# 2          1977  Romance ,Drama                      6.6   Ramesh Talwar
#
#       Producer    Verdict
# 0  Yash Chopra  Super Hit
# 1  Yash Chopra  Super Hit
# 2  Yash Chopra        Hit

# %%
df.isnull().sum()
# Out:
#  YRF Movies(Produced)                  0
# Box Office Collection (India in CR)    4
# Budget (in Cr)                         4
# Release Year                           0
# Genre                                  0
# IMDB Rating (out of 10)                0
# Director's Name                        0
# Producer                               0
# Verdict                                1
# dtype: int64

# %%
df.head(3)
# Out:
#     YRF Movies(Produced)  Box Office Collection (India in CR)  Budget (in Cr)  \
# 0  Daag : A poem of Love                                 3.25            0.95
# 1          Kabhie Kabhie                                 4.00            1.20
# 2           Doosra Aadmi                                  NaN             NaN
#
#    Release Year           Genre  IMDB Rating (out of 10) Director's Name  \
# 0          1973  Romance ,Drama                      7.0     Yash Chopra
# 1          1976  Romance ,Drama                      7.2     Yash Chopra
# 2          1977  Romance ,Drama                      6.6   Ramesh Talwar
#
#       Producer    Verdict
# 0  Yash Chopra  Super Hit
# 1  Yash Chopra  Super Hit
# 2  Yash Chopra        Hit

# %%
df.isnull().sum()
# Out:
#  YRF Movies(Produced)                  0
# Box Office Collection (India in CR)    0
# Budget (in Cr)                         0
# Release Year                           0
# Genre                                  0
# IMDB Rating (out of 10)                0
# Director's Name                        0
# Producer                               0
# Verdict                                0
# dtype: int64

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\yrf.csv")

# %%
df
# Out:
#        YRF Movies(Produced)  Box Office Collection (India in CR)  \
# 0     Daag : A poem of Love                                 3.25
# 1             Kabhie Kabhie                                 4.00
# 2              Doosra Aadmi                                 2.00
# 3                    Noorie                                 2.50
# 4             Kaala Patthar                                 3.00
# ..                      ...                                  ...
# 78      Samraat Prithiviraj                                68.00
# 79                Shamshera                                42.00
# 80                  Pathaan                               543.00
# 81  The Great Indian family                                 5.00
# 82                  Tiger 3                               450.00
#
#     Budget (in Cr)  Release Year                    Genre  \
# 0             0.95          1973           Romance ,Drama
# 1             1.20          1976           Romance ,Drama
# ...

# %%
df.describe()
# Out:
#        Box Office Collection (India in CR)  Budget (in Cr)  Release Year  \
# count                            83.000000       83.000000     83.000000
# mean                             56.458675       45.198795   2006.048193
# std                              97.859134       69.866386     12.583287
# min                               0.350000        0.750000   1973.000000
# 25%                               7.000000        8.500000   2002.000000
# 50%                              26.000000       21.000000   2009.000000
# 75%                              47.000000       37.000000   2014.000000
# max                             543.000000      300.000000   2023.000000
#
#        IMDB Rating (out of 10)
# count                83.000000
# mean                  6.225301
# std                   1.144749
# min                   3.000000
# 25%                   5.500000
# 50%                   6.200000
# 75%                   7.100000
# max                   8.100000

# %%
max = 543.00

# %%
x=df[df['Box Office Collection (India in CR)']<=max]

# %%
sns.boxplot(df['IMDB Rating (out of 10)'])
plt.show(

)

# %%
sns.boxplot(x['Box Office Collection (India in CR)'])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
s=StandardScaler()
df['st']=s.fit_transform(df[['Box Office Collection (India in CR)']])

# %%
df
# Out:
#        YRF Movies(Produced)  Box Office Collection (India in CR)  \
# 0     Daag : A poem of Love                                 3.25
# 1             Kabhie Kabhie                                 4.00
# 2              Doosra Aadmi                                 2.00
# 3                    Noorie                                 2.50
# 4             Kaala Patthar                                 3.00
# ..                      ...                                  ...
# 78      Samraat Prithiviraj                                68.00
# 79                Shamshera                                42.00
# 80                  Pathaan                               543.00
# 81  The Great Indian family                                 5.00
# 82                  Tiger 3                               450.00
#
#     Budget (in Cr)  Release Year                    Genre  \
# 0             0.95          1973           Romance ,Drama
# 1             1.20          1976           Romance ,Drama
# ...

# %%
sns.boxplot(df['st'])
plt.show()

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\yrf.csv")

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['Verdict'].unique()
# Out:
# array([5, 4, 1, 6, 2, 3, 0, 7])

# %%
la = LabelEncoder()
la.fit_transform(df[' YRF Movies(Produced)'])
# Out:
# array([13, 37, 23, 55, 36, 52, 68, 65, 46, 26, 80, 12, 43, 15,  1, 82, 22,
#        21, 50, 48, 51, 62, 31, 17, 79,  9, 63, 53, 28, 18, 38, 35, 11, 71,
#        40,  2, 72, 74,  4, 60, 59, 54, 20, 61, 57,  5, 42,  6, 47, 41, 32,
#        25, 33,  3, 67, 19, 29,  0,  8, 78, 44, 14, 39, 24, 16, 27, 70,  7,
#        49, 58, 77, 30, 75, 69, 81, 45, 10, 34, 64, 66, 56, 73, 76])

# %%
df[' YRF Movies(Produced)'] = la.transform(df[' YRF Movies(Produced)'])

# %%
df
# Out:
#      YRF Movies(Produced)  Box Office Collection (India in CR)  \
# 0                      13                                 3.25
# 1                      37                                 4.00
# 2                      23                                 2.00
# 3                      55                                 2.50
# 4                      36                                 3.00
# ..                    ...                                  ...
# 78                     64                                68.00
# 79                     66                                42.00
# 80                     56                               543.00
# 81                     73                                 5.00
# 82                     76                               450.00
#
#     Budget (in Cr)  Release Year  Genre  IMDB Rating (out of 10)  \
# 0             0.95          1973     10                      7.0
# 1             1.20          1976     10                      7.2
# ...

# %%
x=df.iloc[:,1:]
x
# Out:
#     Box Office Collection (India in CR)  Budget (in Cr)  Release Year  Genre  \
# 0                                  3.25            0.95          1973     10
# 1                                  4.00            1.20          1976     10
# 2                                  2.00            3.00          1977     10
# 3                                  2.50           75.00          1979     11
# 4                                  3.00            2.50          1979      0
# ..                                  ...             ...           ...    ...
# 78                                68.00          300.00          2022      8
# 79                                42.00          150.00          2022      0
# 80                               543.00          250.00          2023     16
# 81                                 5.00           55.00          2023      7
# 82                               450.00          300.00          2023     16
#
# ...

# %%
y=df[' YRF Movies(Produced)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test  =  train_test_split(x,y,test_size=0.2,random_state=42)

# %%
sns.pairplot(data=df)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)*100
# Out:
# 3.8932943683754107

# %%
lr.predict(x_train)
# Out:
# array([45.51465635, 31.40429685, 32.41091538, 46.83152892, 32.23854273,
#        40.89678388, 34.41109013, 44.65479044, 35.39231921, 43.9146264 ,
#        56.89277299, 26.07162693, 40.58733272, 46.74914174, 74.88365808,
#        40.13582332, 65.24316723, 35.04241485, 36.85476129, 33.50504953,
#        39.20074001, 41.4352652 , 34.1821022 , 35.32017879, 51.60976012,
#        31.35275912, 41.71673071, 36.53294564, 46.63831549, 41.99112796,
#        48.20887035, 42.18624165, 44.08180203, 35.44947823, 40.82159554,
#        40.83018726, 38.93195004, 49.36973414, 36.83941369, 41.8354357 ,
#        38.32709618, 39.07180856, 35.21401831, 52.57308895, 35.84372705,
#        31.45999667, 39.43754622, 36.70617051, 67.0207679 , 40.41416295,
#        31.15456712, 58.96380582, 41.77916421, 41.578988  , 42.19461736,
#        43.32237635, 40.00570272, 43.30623341, 38.06812996, 43.63837523,
#        54.42412689, 38.31385918, 35.40690048, 33.4458952 , 35.35657442,
#        47.80236751])

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Prediction

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.predict([[76	,450.00,	300.00,	2023	,16,	5.7,	18	,0]])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([2])

# %%
x=df.iloc[:,:-1]
x
# Out:
#      YRF Movies(Produced)  Box Office Collection (India in CR)  \
# 0                      13                                 3.25
# 1                      37                                 4.00
# 2                      23                                 2.00
# 3                      55                                 2.50
# 4                      36                                 3.00
# ..                    ...                                  ...
# 78                     64                                68.00
# 79                     66                                42.00
# 80                     56                               543.00
# 81                     73                                 5.00
# 82                     76                               450.00
#
#     Budget (in Cr)  Release Year  Genre  IMDB Rating (out of 10)  \
# 0             0.95          1973     10                      7.0
# 1             1.20          1976     10                      7.2
# ...

# %%
y=df['Verdict']

# %%
rf.score(x_test,y_test),rf.score(x_train,y_train)
# Out:
# (0.29411764705882354, 1.0)
